# %% [markdown]
# <a href="https://colab.research.google.com/github/brianbaert/RM4AI_YOLO_Project/blob/main/RM4AI_Project_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.9/496.9 KB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 7.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from IPython.display import display, Image

model = YOLO('yolov8n.pt')
model.predict(source='https://www.thetrendspotter.net/wp-content/uploads/2018/11/Midi-Dress.jpg', conf=0.25, save=True)
# Out:
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
#
# Found https://www.thetrendspotter.net/wp-content/uploads/2018/11/Midi-Dress.jpg locally at Midi-Dress.jpg
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# image 1/1 /content/Midi-Dress.jpg: 640x448 10 persons, 1 traffic light, 205.5ms
# Speed: 1.6ms preprocess, 205.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# [{ '_keys': ('boxes', 'masks', 'probs'),
#    'boxes': ultralytics.yolo.engine.results.Boxes
#  type:  torch.Tensor
#  shape: torch.Size([11, 6])
#  dtype: torch.float32
#  tensor([[9.70102e+01, 1.29854e+02, 2.60767e+02, 5.42629e+02, 8.70414e-01, 0.00000e+00],
#          [3.04020e+02, 6.11851e+01, 3.40818e+02, 1.31752e+02, 8.24239e-01, 9.00000e+00],
#          [3.01081e+02, 1.73561e+02, 3.67988e+02, 3.94196e+02, 8.00274e-01, 0.00000e+00],
# ...

# %%
from PIL import Image, ImageDraw
im = Image.open('/content/runs/detect/predict/Midi-Dress.jpg')
im.show()
# Out:
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x600 at 0x7F739E0450A0>
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.

# %%
## see https://learnopencv.com/train-yolov8-on-custom-dataset/
